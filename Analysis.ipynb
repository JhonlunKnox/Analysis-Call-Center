# %% [markdown]
# # CALL CENTER DATASET ANALYSIS
# ### AUTOR: JUAN PABLO LUNA ZULETA
# ### GITHUB: github.com/JhonlunKnox

# %%
###------------------ IMPORTAR LIBRERÍAS ────────────────────────────────────
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Estilo general de las gráficas
sns.set_theme(style="darkgrid", palette="deep")
plt.rcParams.update({
    'figure.facecolor': '#0f0f17',
    'axes.facecolor':   '#1a1a28',
    'axes.edgecolor':   '#2a2a42',
    'axes.labelcolor':  '#a8a8c8',
    'xtick.color':      '#7878a0',
    'ytick.color':      '#7878a0',
    'text.color':       '#e8e6f0',
    'grid.color':       '#2a2a42',
    'figure.dpi':       120,
})
PURPLE = '#a855f7'
ACCENT = '#c084fc'

# %%
df = pd.read_csv('Data\\Call_Center_Data.csv')

print(" Dataset cargado correctamente")
print(f"   Filas: {df.shape[0]:,}  |  Columnas: {df.shape[1]}")
print("\n Primeras filas:")
print(df.head())
print("\n Tipos de columnas:")
print(df.dtypes)
print("\n Valores nulos por columna:")
print(df.isnull().sum())
# Out:
#  Dataset cargado correctamente
#    Filas: 1,251  |  Columnas: 9
#
#  Primeras filas:
#    Index  Incoming Calls  Answered Calls Answer Rate  Abandoned Calls  \
# 0      1             217             204      94.01%               13
# 1      2             200             182      91.00%               18
# 2      3             216             198      91.67%               18
# 3      4             155             145      93.55%               10
# 4      5              37              37     100.00%                0
#
#   Answer Speed (AVG) Talk Duration (AVG) Waiting Time (AVG)  \
# 0            0:00:17             0:02:14            0:02:45
# 1            0:00:20             0:02:22            0:06:55
# 2            0:00:18             0:02:38            0:03:50
# 3            0:00:15             0:02:29            0:03:12
# 4            0:00:03             0:02:06            0:00:35
#
#   Service Level (20 Seconds)
# 0                     76.28%
# 1                     72.73%
# 2                     74.30%
# 3                     79.61%
# 4                     97.30%
#
#  Tipos de columnas:
# Index                          int64
# Incoming Calls                 int64
# Answered Calls                 int64
# Answer Rate                   object
# Abandoned Calls                int64
# Answer Speed (AVG)            object
# Talk Duration (AVG)           object
# Waiting Time (AVG)            object
# Service Level (20 Seconds)    object
# dtype: object
#
#  Valores nulos por columna:
# Index                         0
# Incoming Calls                0
# Answered Calls                0
# Answer Rate                   0
# Abandoned Calls               0
# Answer Speed (AVG)            0
# Talk Duration (AVG)           0
# Waiting Time (AVG)            0
# Service Level (20 Seconds)    0
# dtype: int64

# %%
df.head()
# Out:
#    Index  Incoming Calls  Answered Calls Answer Rate  Abandoned Calls  \
# 0      1             217             204      94.01%               13
# 1      2             200             182      91.00%               18
# 2      3             216             198      91.67%               18
# 3      4             155             145      93.55%               10
# 4      5              37              37     100.00%                0
#
#   Answer Speed (AVG) Talk Duration (AVG) Waiting Time (AVG)  \
# 0            0:00:17             0:02:14            0:02:45
# 1            0:00:20             0:02:22            0:06:55
# 2            0:00:18             0:02:38            0:03:50
# 3            0:00:15             0:02:29            0:03:12
# 4            0:00:03             0:02:06            0:00:35
#
#   Service Level (20 Seconds)
# 0                     76.28%
# 1                     72.73%
# 2                     74.30%
# 3                     79.61%
# 4                     97.30%

# %%
# ── LIMPIEZA DE DATOS ─────────────────────────────────────
print("\n Limpiando datos...")

# Eliminar duplicados
antes = len(df)
df.drop_duplicates(inplace=True)
print(f"   Duplicados eliminados: {antes - len(df)}")


# Rellenar nulos en columnas de texto
text_cols = df.select_dtypes(include='object').columns
df[text_cols] = df[text_cols].fillna('Desconocido')

print(f"\n Dataset limpio: {len(df):,} registros listos para analizar")
print("\n Resumen estadístico:")
print(df.describe(include='all'))
# Out:
#  Limpiando datos...
#    Duplicados eliminados: 0
#
#  Dataset limpio: 1,251 registros listos para analizar
#
#  Resumen estadístico:
#               Index  Incoming Calls  Answered Calls Answer Rate  \
# count   1251.000000     1251.000000     1251.000000        1251
# unique          NaN             NaN             NaN         730
# top             NaN             NaN             NaN     100.00%
# freq            NaN             NaN             NaN          81
# mean     626.000000      198.539568      176.845723         NaN
# min        1.000000        5.000000        5.000000         NaN
# 25%      313.500000      123.000000      114.000000         NaN
# 50%      626.000000      177.000000      166.000000         NaN
# 75%      938.500000      233.000000      214.500000         NaN
# max     1251.000000     1575.000000      909.000000         NaN
# std      361.276902      156.534195      115.612080         NaN
#
#         Abandoned Calls Answer Speed (AVG) Talk Duration (AVG)  \
# count       1251.000000               1251                1251
# unique              NaN                 93                 131
# top                 NaN            0:00:26             0:02:39
# freq                NaN                 47                  29
# mean          21.693845                NaN                 NaN
# min            0.000000                NaN                 NaN
# 25%            3.000000                NaN                 NaN
# 50%            8.000000                NaN                 NaN
# 75%           16.000000                NaN                 NaN
# max          704.000000                NaN                 NaN
# std           59.671955                NaN                 NaN
#
#                    Waiting Time (AVG) Service Level (20 Seconds)
# count                            1251                       1251
# unique                            NaN                       1027
# top                               NaN                    100.00%
# freq                              NaN                         13
# mean    2026-03-08 00:03:52.314948096                        NaN
# min               2026-03-08 00:00:03                        NaN
# 25%               2026-03-08 00:01:58                        NaN
# 50%               2026-03-08 00:03:02                        NaN
# 75%               2026-03-08 00:04:36                        NaN
# max               2026-03-08 00:25:51                        NaN
# std                               NaN                        NaN
